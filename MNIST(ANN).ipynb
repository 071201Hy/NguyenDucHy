# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.datasets import mnist, fashion_mnist, cifar10, cifar100
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from keras.utils import np_utils
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_history(history_fine):
  f1 = history_fine.history['acc']
  val_f1 = history_fine.history['val_acc']

  loss = history_fine.history['loss']
  val_loss = history_fine.history['val_loss']

  plt.figure(figsize=(8, 8))
  plt.subplot(2, 1, 1)
  plt.plot(f1, label='Acc')
  plt.plot(val_f1, label='Validation Acc')
  plt.legend(loc='lower right')
  plt.title('Accuracy')

  plt.subplot(2, 1, 2)
  plt.plot(loss, label='Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Loss')
  plt.xlabel('epoch')
  plt.show()

# %%
# Load Data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_pre = x_test[0]
y_pre = y_test[0]

# Reshape Data
x_train = x_train.reshape(x_train.shape[0], -1)
x_test = x_test.reshape(x_test.shape[0], -1)

# Preprocessing Data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Encoding Y
y_train = np_utils.to_categorical(y_train, 10)
y_test = np_utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_shape = (784,)))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer =Adam(), metrics=['acc'])

history = model.fit(x_train, y_train, batch_size = 128, epochs = 20, validation_split = 0.2)

plot_history(history)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 2s 3ms/step - loss: 0.8318 - acc: 0.7697 - val_loss: 0.4054 - val_acc: 0.8913
# Epoch 2/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3824 - acc: 0.8961 - val_loss: 0.3228 - val_acc: 0.9102
# Epoch 3/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3290 - acc: 0.9086 - val_loss: 0.2962 - val_acc: 0.9187
# Epoch 4/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3037 - acc: 0.9152 - val_loss: 0.2811 - val_acc: 0.9201
# Epoch 5/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2884 - acc: 0.9190 - val_loss: 0.2746 - val_acc: 0.9217
# Epoch 6/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2765 - acc: 0.9221 - val_loss: 0.2649 - val_acc: 0.9255
# Epoch 7/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2673 - acc: 0.9241 - val_loss: 0.2555 - val_acc: 0.9287
# Epoch 8/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2600 - acc: 0.9265 - val_loss: 0.2539 - val_acc: 0.9287
# Epoch 9/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2530 - acc: 0.9287 - val_loss: 0.2505 - val_acc: 0.9290
# Epoch 10/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2479 - acc: 0.9293 - val_loss: 0.2479 - val_acc: 0.9296
# Epoch 11/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2422 - acc: 0.9309 - val_loss: 0.2457 - val_acc: 0.9308
# Epoch 12/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2390 - acc: 0.9321 - val_loss: 0.2434 - val_acc: 0.9304
# Epoch 13/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2351 - acc: 0.9333 - val_loss: 0.2419 - val_acc: 0.9322
# Epoch 14/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2317 - acc: 0.9342 - val_loss: 0.2410 - val_acc: 0.9326
# Epoch 15/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2287 - acc: 0.9349 - val_loss: 0.2358 - val_acc: 0.9334
# Epoch 16/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2256 - acc: 0.9360 - val_loss: 0.2360 - val_acc: 0.9330
# Epoch 17/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2215 - acc: 0.9370 - val_loss: 0.2374 - val_acc: 0.9327
# Epoch 18/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2192 - acc: 0.9372 - val_loss: 0.2343 - val_acc: 0.9348
# Epoch 19/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2169 - acc: 0.9381 - val_loss: 0.2302 - val_acc: 0.9367
# Epoch 20/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2140 - acc: 0.9391 - val_loss: 0.2306 - val_acc: 0.9347

# %%
model1 = Sequential()
model1.add(Dense(10, activation='relu', input_shape = (784,)))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(10, activation='softmax'))

model1.compile(loss='categorical_crossentropy', optimizer =Adam(), metrics=['acc'])

history1 = model1.fit(x_train, y_train, batch_size = 128, epochs = 10, validation_split = 0.2)

plot_history(history1)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 3s 5ms/step - loss: 1.2384 - acc: 0.6005 - val_loss: 0.5559 - val_acc: 0.8378
# Epoch 2/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5045 - acc: 0.8549 - val_loss: 0.4058 - val_acc: 0.8840
# Epoch 3/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4104 - acc: 0.8845 - val_loss: 0.3525 - val_acc: 0.8990
# Epoch 4/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3550 - acc: 0.8985 - val_loss: 0.3185 - val_acc: 0.9109
# Epoch 5/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3189 - acc: 0.9089 - val_loss: 0.2942 - val_acc: 0.9161
# Epoch 6/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2976 - acc: 0.9139 - val_loss: 0.2880 - val_acc: 0.9154
# Epoch 7/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2794 - acc: 0.9192 - val_loss: 0.2765 - val_acc: 0.9217
# Epoch 8/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2658 - acc: 0.9240 - val_loss: 0.2622 - val_acc: 0.9245
# Epoch 9/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2542 - acc: 0.9266 - val_loss: 0.2497 - val_acc: 0.9292
# Epoch 10/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2438 - acc: 0.9279 - val_loss: 0.2496 - val_acc: 0.9301

# %%
model2 = Sequential()
model2.add(Dense(10, activation='relu', input_shape = (784,)))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='softmax'))

model2.compile(loss='categorical_crossentropy', optimizer =Adam(), metrics=['acc'])

history2 = model2.fit(x_train, y_train, batch_size = 128, epochs = 10, validation_split = 0.2)

plot_history(history2)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 3s 4ms/step - loss: 1.7350 - acc: 0.3416 - val_loss: 1.2267 - val_acc: 0.6472
# Epoch 2/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.8718 - acc: 0.7235 - val_loss: 0.6792 - val_acc: 0.7757
# Epoch 3/10
# 375/375 [==============================] - 2s 4ms/step - loss: 0.6397 - acc: 0.7939 - val_loss: 0.5754 - val_acc: 0.8201
# Epoch 4/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5580 - acc: 0.8322 - val_loss: 0.5186 - val_acc: 0.8474
# Epoch 5/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4977 - acc: 0.8571 - val_loss: 0.4721 - val_acc: 0.8688
# Epoch 6/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4582 - acc: 0.8720 - val_loss: 0.4640 - val_acc: 0.8692
# Epoch 7/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4306 - acc: 0.8793 - val_loss: 0.4190 - val_acc: 0.8879
# Epoch 8/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4083 - acc: 0.8875 - val_loss: 0.4051 - val_acc: 0.8926
# Epoch 9/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3912 - acc: 0.8919 - val_loss: 0.4163 - val_acc: 0.8904
# Epoch 10/10
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3794 - acc: 0.8950 - val_loss: 0.3972 - val_acc: 0.8941

# %%
loss_dict = {
  "1-10": history.history['val_acc'],
  "5-10": history1.history['val_acc'],
  "10-10": history2.history['val_acc']
}

# %%
x = []
y = []
yerr = []
for k, v in loss_dict.items():
    x.append(k)
    y.append(np.mean(v))  # compute mean
    yerr.append([np.mean(v) - min(v), max(v) - np.mean(v)])  # use max and min as upper and lower bound

yerr = np.transpose(yerr)  # yerr should be 2xN matrix
plt.errorbar(x, y, yerr=yerr, color='b')
plt.xlabel("Models_Architecture")
plt.ylabel('value')
plt.title("Val_Accuracy")
plt.grid(b=True, color='g')
plt.show()

# %%
plt.title("Model 1 Hidden và 10 Neuron dự đoán là: " + str(np.argmax(model1.predict(x_pre.reshape((-1,28*28))))))
plt.imshow(x_pre, cmap=plt.get_cmap('gray'))

# %%
from google.colab import drive
drive.mount('/content/drive')
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('MNIST(ANN).ipynb')
# Out:
# Mounted at /content/drive
# --2022-05-18 15:47:21--  https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1864 (1.8K) [text/plain]
# Saving to: ‘colab_pdf.py’
#
# colab_pdf.py        100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2022-05-18 15:47:21 (23.7 MB/s) - ‘colab_pdf.py’ saved [1864/1864]
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Extracting templates from packages: 100%
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/MNIST(ANN).ipynb to pdf
# [NbConvertApp] Support files will be in MNIST(ANN)_files/
# [NbConvertApp] Making directory ./MNIST(ANN)_files
# [NbConvertApp] Making directory ./MNIST(ANN)_files
# [NbConvertApp] Making directory ./MNIST(ANN)_files
# [NbConvertApp] Making directory ./MNIST(ANN)_files
# [NbConvertApp] Making directory ./MNIST(ANN)_files
# [NbConvertApp] Writing 46102 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', './notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', './notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 122499 bytes to /content/drive/My Drive/MNIST(ANN).pdf
# 'File ready to be Downloaded and Saved to Drive'
